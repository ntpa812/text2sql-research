# %%
# !python3 app.py data/user_questions/test_sets/uq_test_mixed.csv --no-explain --parallel 4   
# llama3
# Out:
# ...
#   Batch Mode — uq_test_mixed.csv
#   explain=OFF | parallel=4
# ...
# Loaded 20 questions
#
# 10:14:17 [INFO] Đã lưu 20 questions vào /home/tts/aiPhuongAnh/6804_ddq/Text2SQL_Template/data/user_questions/processed/questions.json
# Running 20 queries with 4 threads...
#
# 10:14:17 [INFO] [Pipeline] Loading domain registry...
# 10:14:17 [INFO] [Pipeline] Loading domain registry...
# 10:14:17 [INFO] [Pipeline] Loading domain registry...
# 10:14:17 [INFO]
# ...
# 10:14:17 [INFO]
# ...
# 10:14:17 [INFO] [Step 0] Domain Router
# 10:14:17 [INFO] [Step 0] Domain Router
# 10:14:17 [INFO]
# ...
# 10:14:17 [INFO] [Step 0] Candidate domains: ['banking'] (0.001s)
# 10:14:17 [INFO]
# ...
# 10:14:17 [INFO] [Step 0] Candidate domains: ['banking'] (0.001s)
# 10:14:17 [INFO] [Step 1] Schema Router
# 10:14:17 [INFO] [Step 1] Schema Router
# 10:14:17 [INFO] [Step 0] Domain Router
# 10:14:17 [INFO] [Pipeline] Loading resources for domain=banking...
# 10:14:17 [INFO] [Pipeline] Loading resources for domain=banking...
# ...

# %%
# !python3 evaluation/evaluate_pipeline.py --no-explain
# Out:
# Loaded 25 test cases from /home/tts/aiPhuongAnh/6804_ddq/Text2SQL_Template/data/evaluation/gold_test_set.jsonl
#
# [1/25] test_001: Cho tôi xem giao dịch chuyển tiền tài khoản 123456789 trong ...
#   PASS
# [2/25] test_002: Tổng số tiền tôi đã nhận trong tuần này...
#   PASS
# [3/25] test_003: Liệt kê các giao dịch trên 50 triệu trong năm 2024...
#   FAIL: intent(tra_cứu_giao_dịch_chuyển_tiền_->tra_cứu_giao_dịch_vay_và_tín_d)
# [4/25] test_004: Giao dịch ngoại tệ USD của tài khoản 9876543210...
#   FAIL: sql(missing=['9876543210'])
# [5/25] test_005: Các giao dịch rút tiền qua ATM trong tháng trước...
# ...

# %%
# !python app.py data/user_questions/test_sets/uq_test_1.csv --warm --parallel 4 
# llama3
# Out:
# 10:02:18 [INFO] [LLM] Warming up OpenAI-compatible model...
# 10:02:29 [INFO] [LLM-OpenAI] Content empty, trying to extract SQL from reasoning_content
# 10:02:29 [WARNING] [LLM-OpenAI] Empty content and no SQL in reasoning (finish_reason=length). Message excerpt: {'role': 'assistant', 'content': None, 'refusal': None, 'annotations': None, 'audio': None, 'function_call': None, 'tool_calls': [], 'reasoning': 'Okay, the user just sent "SELECT'}
# 10:02:29 [INFO] [LLM] OpenAI-compatible warm-up done.
#
# ...
#   Batch Mode — uq_test_1.csv
#   explain=ON | parallel=4
# ...
# Loaded 35 questions
#
# 10:02:29 [INFO] Đã lưu 35 questions vào /home/tts/aiPhuongAnh/6804_ddq/Text2SQL_Template/data/user_questions/processed/questions.json
# Running 35 queries with 4 threads...
#
# 10:02:29 [INFO] [Pipeline] Loading domain registry...
# 10:02:29 [INFO]
# ...
# 10:02:29 [INFO] [Step 0] Domain Router
# 10:02:29 [INFO] [Step 0] Candidate domains: ['banking'] (0.001s)
# 10:02:29 [INFO] [Step 1] Schema Router
# ...

# %%
# !python app.py data/user_questions/test_sets/banking_basic.json --no-explain
# Out:
# ...
#   Batch Mode — banking_basic.json
#   explain=OFF | parallel=1
# ...
# Loaded 5 questions
#
#
# ────────────────────────────────────────────────────────────
# [1/5] Processing...
# ────────────────────────────────────────────────────────────
#
# User Question: Tra cứu giao dịch chuyển tiền tới số tài khoản 123 trong tháng 1
# → Domain: banking
# → Candidate Domains: ['banking']
# → Tables: ['transaction', 'customer_account', 'customer']
# → Intent: tra_cứu_giao_dịch_chuyển_tiền_theo_số_tài_khoản_người_nhận
# → Entities: {'amount': '123000000'}
# → SQL: SELECT SUM(t.amount_transfer) AS total_transfer
# FROM transaction t
# JOIN customer_account c ON t.from_account_no = c.account_no
# WHERE c.account_no = '123456789'
# AND t.category_code LIKE 'TRANSFER_%'
# ORDER BY t.trans_time DESC;
# → Validator: PASS
# → Domain Routing: single_candidate
# → Result: 1 rows
# → Confidence: 0.93 (PASS)
# → Structure: 0.75
# ...

# %%
# !python test_repair_integration.py data/user_questions/test_sets/banking_basic.json
# Out:
# ...
# Testing Repair-First Strategy Integration
# ...
#
# Running 5 test questions...
#
# [1/5] Tra cứu giao dịch chuyển tiền tới số tài khoản 123 trong thá...
# 2026-03-23 14:38:45,577 [pipeline.pipeline_runner] INFO: [Pipeline] Loading semantic profiles...
# 2026-03-23 14:38:45,580 [pipeline.pipeline_runner] INFO: [Pipeline] Loading intent dataset...
# 2026-03-23 14:38:45,584 [pipeline.pipeline_runner] INFO: [Pipeline] Loading approved templates...
# 2026-03-23 14:38:45,588 [template_store.template_loader] INFO: [Template] Loaded 17 approved templates.
# 2026-03-23 14:38:45,588 [pipeline.pipeline_runner] INFO:
# ...
# 2026-03-23 14:38:45,588 [pipeline.pipeline_runner] INFO: [Step 1] Schema Router
# 2026-03-23 14:38:45,591 [schema_router.schema_loader] INFO: [SchemaLoader] Building schema description for tables: ['customer_account', 'transaction']
# 2026-03-23 14:38:45,591 [pipeline.pipeline_runner] INFO: [Step 1] Selected tables: ['customer_account', 'transaction'] (0.003s)
# ...

# %%
# !python app.py data\user_questions\test_sets\uq_test_1.csv --warm --parallel 4
# Out:
# ...
#   Batch Mode — uq_test_1.csv
#   explain=ON | parallel=4
# ...
# Loaded 35 questions
#
# Running 35 queries with 4 threads...
#
#
# ────────────────────────────────────────────────────────────
# [1/35]
#
# User Question: Xem tất cả giao dịch của tài khoản 123456 trong tháng 1 năm 2024
# → Tables: ['customer_account', 'transaction']
# → Intent: tra_cứu_giao_dịch_tiết_kiệm_theo_tài_khoản_nguồn
# → Entities: {'account_no': '123456', 'amount': '123456000000'}
# → SQL: SELECT trans_id, trans_time, trans_type, trans_name,
#        from_account_no, to_account_no,
#        amount_transfer, amount_currency,
#        trans_status, trans_desc
# FROM transaction
# WHERE category_code LIKE 'SAVING_%'
# AND from_account_no = '123456'
# ORDER BY trans_time DESC;
# → Validator: PASS_EMPTY
# → Result: 0 rows (dữ liệu không tồn tại, SQL hợp lệ)
# → Cache: HIT (skip pipeline)
# → Timing: cache_hit=0.0s | total=0.03s
#
# ────────────────────────────────────────────────────────────
# [2/35]
#
# ...

# %%
# !python app.py data\user_questions\test_sets\uq_test_2.csv --no-explain --warm --parallel 4
# Out:
# ...
#   Batch Mode — uq_test_2.csv
#   explain=OFF | parallel=4
# ...
# Loaded 50 questions
#
# Running 50 queries with 4 threads...
#
#
# ────────────────────────────────────────────────────────────
# [1/50]
#
# User Question: Tôi đã chuyển bao nhiêu tiền trong tháng này
# → Tables: ['customer', 'customer_account', 'transaction']
# → Intent: tra_cứu_giao_dịch_chuyển_tiền_theo_thời_gian
# → Entities: {}
# → SQL: SELECT
#   SUM(amount_transfer) AS total_transfer
# FROM
#   transaction
# WHERE
#   category_code LIKE 'TRANSFER_%' OR category_code = 'REQUEST_TRANSFER'
# AND
#   from_account_no = 'your_account_number'
# AND
#   trans_time BETWEEN '2023-01-01' AND '2023-01-31'
# → Validator: PASS
#   ⚠ Câu hỏi yêu cầu đếm (COUNT) nhưng SQL thiếu COUNT()
#   ⚠ Câu hỏi có thời gian nhưng SQL thiếu filter thời gian
# → Result: 1 rows
# → Confidence: 0.9 (PASS)
# → Structure: 1.0
# ...

# %%
# new model hf.co/defog/sqlcoder-7b-2:Q5_K_M
# !python app.py data\user_questions\test_sets\uq_test_1.csv --no-explain --warm --parallel 4
# Out:
# ...
#   Batch Mode — uq_test_1.csv
#   explain=OFF | parallel=4
# ...
# Loaded 35 questions
#
# Running 35 queries with 4 threads...
#
#
# ────────────────────────────────────────────────────────────
# [1/35]
#
# User Question: Xem tất cả giao dịch của tài khoản 123456 trong tháng 1 năm 2024
# → Tables: ['customer_account', 'transaction']
# → Intent: tra_cứu_giao_dịch_tiết_kiệm_theo_tài_khoản_nguồn
# → Entities: {'account_no': '123456', 'amount': '123456000000'}
# → SQL: SELECT trans_id, trans_time, trans_type, trans_name,
#        from_account_no, to_account_no,
#        amount_transfer, amount_currency,
#        trans_status, trans_desc
# FROM transaction
# WHERE category_code LIKE 'SAVING_%'
# AND from_account_no = '123456'
# ORDER BY trans_time DESC;
# → Validator: PASS_EMPTY
# → Result: 0 rows (dữ liệu không tồn tại, SQL hợp lệ)
# → Cache: HIT (skip pipeline)
# → Timing: cache_hit=0.0s | total=0.04s
#
# ────────────────────────────────────────────────────────────
# [2/35]
#
# ...

# %%
# run after upgrade validatior 
# !python app.py data\user_questions\test_sets\uq_test_1.csv --no-explain --warm --parallel 4
# Out:
# 11:39:53 [INFO] [LLM] Warming up Ollama model...
# 11:40:01 [INFO] [LLM] Ollama warm-up done.
# 11:40:02 [INFO] Đã lưu 35 questions vào e:\proton-intern\javisAI\6804_ddq\Text2SQL_Template\data\user_questions\processed\questions.json
# 11:40:02 [INFO] [Pipeline] Loading semantic profiles...
# 11:40:02 [INFO] [Pipeline] Loading semantic profiles...
# 11:40:02 [INFO] [Pipeline] Loading semantic profiles...
# 11:40:02 [INFO] [Pipeline] Loading semantic profiles...
# 11:40:02 [INFO] [Pipeline] Loading intent dataset...
# 11:40:02 [INFO] [Pipeline] Loading intent dataset...
# 11:40:02 [INFO] [Pipeline] Loading intent dataset...
# 11:40:02 [INFO] [Pipeline] Loading intent dataset...
# 11:40:02 [INFO] [Pipeline] Loading approved templates...
# 11:40:02 [INFO] [Pipeline] Loading approved templates...
# 11:40:02 [INFO] [Pipeline] Loading approved templates...
# 11:40:02 [INFO] [Pipeline] Loading approved templates...
# 11:40:02 [INFO] [Template] Loaded 12 approved templates.
# ...

# %%
# Fast benchmark (no explain, warm model first)
# !python app.py data\user_questions\test_sets\uq_test_1.csv --no-explain --warm
# Out:
# ...
#   Batch Mode — uq_test_1.csv
#   explain=OFF | parallel=1
# ...
# Loaded 35 questions
#
#
# ────────────────────────────────────────────────────────────
# [1/35] Processing...
# ────────────────────────────────────────────────────────────
#
# User Question: Xem tất cả giao dịch của tài khoản 123456 trong tháng 1 năm 2024
# → Tables: ['customer_account', 'transaction']
# → Intent: tra_cứu_giao_dịch_tiết_kiệm_theo_tài_khoản_nguồn
# → Entities: {'account_no': '123456', 'amount': '123456000000'}
# → SQL: SELECT trans_id, trans_time, trans_type, trans_name,
#        from_account_no, to_account_no,
#        amount_transfer, amount_currency,
#        trans_status, trans_desc
# FROM transaction
# WHERE category_code LIKE 'SAVING_%'
# AND from_account_no = '123456'
# ORDER BY trans_time DESC;
# → Validator: PASS
# → Result: 0 rows
# ...

# %%
# !python app.py data/user_questions/test_sets/uq_test_0.md --no-explain --warm
# Out:
# ...
#   Batch Mode — uq_test_0.md
#   explain=OFF | parallel=1
# ...
# Loaded 3 questions
#
#
# ────────────────────────────────────────────────────────────
# [1/3] Processing...
# ────────────────────────────────────────────────────────────
#
# User Question: Tra cứu giao dịch chuyển tiền tới số tài khoản 123 trong tháng 1
# → Tables: ['customer_account', 'transaction']
# → Intent: tra_cứu_giao_dịch_chuyển_tiền_theo_số_tài_khoản_người_nhận
# → Entities: {'amount': '123000000'}
# → SQL: SELECT
#   trans_id,
#   trans_time,
#   trans_type,
#   trans_name,
#   from_account_no,
#   to_account_no,
#   amount_transfer,
#   amount_currency,
#   trans_status,
#   trans_desc
# FROM
#   transaction
# WHERE
#   (category_code LIKE 'TRANSFER_%' OR category_code = 'REQUEST_TRANSFER')
# AND
#   (from_account_no = '123')
# AND
#   (to_account_no = '123')
# ORDER BY
#   trans_time DESC
# LIMIT 100;
# → Validator: PASS
# → Result: 0 rows
# ...

# %%
# Interactive
# !python app.py
